# %%
"""
@author: Matías Ramírez, Matías González
"""
# Out:
# '\n@author: Matías Ramírez, Matías González\n'

# %%
# !pip install deap
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.23.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from io import StringIO
from deap import base, creator, tools, algorithms

file_path = '/content/drive/MyDrive/vrptw_c101.txt'

with open(file_path, 'r') as file:
    data = file.read()


data_relevant = data.split('SERVICE TIME\n')[1]  # Extracting data after the header
data_stream = StringIO(data_relevant)  # Using StringIO to make it readable by pandas

df = pd.read_csv(data_stream, sep="\s+", header=None)
df.columns = ["CUST NO.", "XCOORD.", "YCOORD.", "DEMAND", "TIEMPO LISTO", "FECHA LÍMITE", "TIEMPO DE SERVICIO"]

df.head()
# Out:
#    CUST NO.  XCOORD.  YCOORD.  DEMAND  TIEMPO LISTO  FECHA LÍMITE  \
# 0         0       40       50       0             0          1236
# 1         1       45       68      10           912           967
# 2         2       45       70      30           825           870
# 3         3       42       66      10            65           146
# 4         4       42       68      10           727           782
#
#    TIEMPO DE SERVICIO
# 0                   0
# 1                  10
# 2                  10
# 3                  10
# 4                  10

# %% [markdown]
# 1.MOACS - ACO generico

# %%
import pandas as pd
import numpy as np

# Establecer semilla aleatoria para reproducibilidad
random_seed = np.random.randint(1, 1000)  # Genera un número aleatorio entre 1 y 1000
np.random.seed(random_seed)

# Calcular la distancia entre dos puntos
def calcular_distancia(punto1, punto2):
    return np.linalg.norm(np.array(punto1) - np.array(punto2))

# Calcular el costo de una ruta dadas las coordenadas de los clientes
def calcular_costo_ruta(ruta, coordenadas):
    distancias = np.linalg.norm(coordenadas[ruta[:-1]] - coordenadas[ruta[1:]], axis=1)
    return np.sum(distancias)

# Inicializar rutas para cada vehículo
def inicializar_rutas(num_clientes):
    return [[i] for i in range(1, num_clientes)]

# Seleccionar el cliente más cercano a uno dado
def seleccionar_cliente_mas_cercano(cliente_actual, clientes_restantes, coordenadas):
    if not clientes_restantes:
        return None
    ubicacion_actual = coordenadas[cliente_actual]
    distancias = np.linalg.norm(coordenadas[clientes_restantes] - ubicacion_actual, axis=1)
    cliente_mas_cercano = clientes_restantes[np.argmin(distancias)]
    return cliente_mas_cercano

# Verificar si se viola la ventana de tiempo
def se_viola_ventana_tiempo(tiempo_actual, distancia, tiempo_listo, fecha_limite, tiempo_servicio):
    return tiempo_actual + distancia + tiempo_servicio > fecha_limite

# Agregar un cliente a una ruta y verificar si se viola la ventana de tiempo
def agregar_cliente_a_ruta(ruta_actual, cliente, tiempo_actual, coordenadas, df, tolerancia_ventana_tiempo):
    if cliente is not None:
        distancia = calcular_distancia(coordenadas[ruta_actual[-1]], coordenadas[cliente])
        tiempo_servicio = df.at[cliente, 'TIEMPO DE SERVICIO']
        tiempo_listo = df.at[cliente, 'TIEMPO LISTO']
        fecha_limite = df.at[cliente, 'FECHA LÍMITE']

        if not se_viola_ventana_tiempo(tiempo_actual, distancia, tiempo_listo, fecha_limite, tiempo_servicio):
            ruta_actual.append(cliente)
            tiempo_actual = max(tiempo_actual + distancia + tiempo_servicio, tiempo_listo)
            return tiempo_actual, True
        else:
            return tiempo_actual, False
    else:
        return tiempo_actual, False

# Inicializar feromonas
def inicializar_feromonas(num_clientes):
    return np.ones((num_clientes, num_clientes)) / num_clientes

# Actualizar feromonas
def actualizar_feromonas(feromonas, rutas, costo_rutas, evaporation_rate=0.5):
    feromonas *= (1.0 - evaporation_rate)  # Evaporación
    for ruta, costo in zip(rutas, costo_rutas):
        for i in range(len(ruta) - 1):
            # Actualización de feromonas utilizando la ecuación clásica
            feromonas[ruta[i], ruta[i + 1]] += 1.0 / costo
            feromonas[ruta[i + 1], ruta[i]] += 1.0 / costo

# Construir solución de la hormiga
def construir_solucion_hormiga(feromonas, visibilidad, tolerancia_ventana_tiempo=0):
    num_clientes = feromonas.shape[0]
    coordenadas = df[['XCOORD.', 'YCOORD.']].values
    ruta_hormiga = [0]  # Comienza en el depósito
    tiempo_actual = 0

    while len(ruta_hormiga) < num_clientes:
        clientes_restantes = [c for c in range(num_clientes) if c not in ruta_hormiga]
        probabilidad = np.zeros(num_clientes)

        for cliente in clientes_restantes:
            probabilidad[cliente] = (feromonas[ruta_hormiga[-1], cliente] ** 1.0) * (visibilidad[ruta_hormiga[-1], cliente] ** 2.0)

        if np.random.rand() < 0.9:
            # Elegir la mejor (explotación)
            siguiente_cliente = np.argmax(probabilidad)
        else:
            # Elegir según la probabilidad proporcional (exploración)
            probabilidad /= np.sum(probabilidad)
            probabilidad[clientes_restantes] /= np.sum(probabilidad[clientes_restantes])
            siguiente_cliente = np.random.choice(clientes_restantes, p=probabilidad[clientes_restantes], replace=False)

        tiempo_actual, agregado = agregar_cliente_a_ruta(ruta_hormiga, siguiente_cliente, tiempo_actual, coordenadas, df, tolerancia_ventana_tiempo)

        if not agregado:
            # Si no se pudo agregar el cliente, regresar al depósito y continuar
            ruta_hormiga.append(0)
            tiempo_actual = 0

    return ruta_hormiga

# Calcular la visibilidad entre las ciudades
def calcular_visibilidad(coordenadas):
    num_clientes = coordenadas.shape[0]
    visibilidad = np.zeros((num_clientes, num_clientes))

    for i in range(num_clientes):
        for j in range(i + 1, num_clientes):
            dist = calcular_distancia(coordenadas[i], coordenadas[j])
            visibilidad[i, j] = 1.0 / dist
            visibilidad[j, i] = 1.0 / dist

    return visibilidad

def moaco(df, num_hormigas, num_iteraciones, tolerancia_ventana_tiempo=0,
          ALPHA=1.0, BETA=2.0, RHO=0.5, Q0=0.9):
    """
    Realiza la optimización de rutas utilizando el Algoritmo de Colonias de Hormigas (MOACO).

    Parámetros:
    - df: DataFrame que contiene la información de los clientes.
    - num_hormigas: Número de hormigas (soluciones) a construir en cada iteración.
    - num_iteraciones: Número de iteraciones del algoritmo.
    - tolerancia_ventana_tiempo: Tolerancia para la ventana de tiempo de los clientes.
    - ALPHA: Peso de la feromona en la elección de la próxima ciudad.
    - BETA: Peso de la visibilidad en la elección de la próxima ciudad.
    - RHO: Tasa de evaporación de la feromona.
    - Q0: Probabilidad de elegir la mejor ciudad (en lugar de basarse en probabilidades).

    Retorna:
    La mejor solución encontrada.
    """
    num_clientes = len(df)
    coordenadas = df[['XCOORD.', 'YCOORD.']].values

    feromonas = inicializar_feromonas(num_clientes)
    visibilidad = calcular_visibilidad(coordenadas)

    mejor_solucion_global = None
    mejor_costo_global = float('inf')

    for iteracion in range(num_iteraciones):
        soluciones_hormigas = []

        for _ in range(num_hormigas):
            solucion_hormiga = construir_solucion_hormiga(feromonas, visibilidad, tolerancia_ventana_tiempo)
            soluciones_hormigas.append(solucion_hormiga)

        costo_rutas_hormigas = [calcular_costo_ruta(solucion, coordenadas) for solucion in soluciones_hormigas]

        # Actualizar feromonas
        actualizar_feromonas(feromonas, soluciones_hormigas, costo_rutas_hormigas, evaporation_rate=RHO)


        # Actualizar mejor solución global
        mejor_indice = np.argmin(costo_rutas_hormigas)
        if costo_rutas_hormigas[mejor_indice] < mejor_costo_global:
            mejor_costo_global = costo_rutas_hormigas[mejor_indice]
            mejor_solucion_global = soluciones_hormigas[mejor_indice]


        promedio_feromonas = np.mean(feromonas)

        # Imprimir información
        print(f"Iteración {iteracion + 1}/{num_iteraciones} - Mejor Costo Global: {mejor_costo_global} - Promedio de Feromonas: {promedio_feromonas}")

    return mejor_solucion_global


# Imprimir la solución (rutas y costos)
# Agregar esto a la función imprimir_solucion
def imprimir_solucion(rutas, df):
    for i, ruta in enumerate(rutas):
        print(f"Ruta {i + 1}: Depósito -> ", end="")
        for cliente in ruta:
            print(f"{cliente} Tiempo Servicio: {df.at[cliente, 'TIEMPO DE SERVICIO']}, Ventana Tiempo: ({df.at[cliente, 'TIEMPO LISTO']}, {df.at[cliente, 'FECHA LÍMITE']})) -> ", end="")
        print("Depósito")
        print(f"Costo Ruta {i + 1}: {calcular_costo_ruta(ruta, df[['XCOORD.', 'YCOORD.']].values)}")
        print()


if __name__ == '__main__':
    print("Dataset")
    print(df)
    print()

    num_hormigas = 10
    num_iteraciones = 50
    tolerancia_ventana_tiempo = 30

    mejor_solucion = moaco(df, num_hormigas, num_iteraciones, tolerancia_ventana_tiempo)

    # Imprimir la mejor solución encontrada
    imprimir_solucion([mejor_solucion], df)
# Out:
# Dataset
#      CUST NO.  XCOORD.  YCOORD.  DEMAND  TIEMPO LISTO  FECHA LÍMITE  \
# 0           0       40       50       0             0          1236
# 1           1       45       68      10           912           967
# 2           2       45       70      30           825           870
# 3           3       42       66      10            65           146
# 4           4       42       68      10           727           782
# ..        ...      ...      ...     ...           ...           ...
# 96         96       60       80      10            95           156
# 97         97       60       85      30           561           622
# 98         98       58       75      20            30            84
# 99         99       55       80      10           743           820
# 100       100       55       85      20           647           726
#
#      TIEMPO DE SERVICIO
# 0                     0
# 1                    10
# 2                    10
# 3                    10
# 4                    10
# ..                  ...
# 96                   10
# 97                   10
# 98                   10
# 99                   10
# 100                  10
#
# [101 rows x 7 columns]
#
# Iteración 1/50 - Mejor Costo Global: 1134.9508449408972 - Promedio de Feromonas: 0.005102827968285776
# Iteración 2/50 - Mejor Costo Global: 1134.9508449408972 - Promedio de Feromonas: 0.0027060162500292893
# Iteración 3/50 - Mejor Costo Global: 1134.9508449408972 - Promedio de Feromonas: 0.001504029524486601
# Iteración 4/50 - Mejor Costo Global: 1134.9508449408972 - Promedio de Feromonas: 0.0009116275376836404
# Iteración 5/50 - Mejor Costo Global: 1134.9508449408972 - Promedio de Feromonas: 0.0006165271303674356
# Iteración 6/50 - Mejor Costo Global: 1134.9508449408972 - Promedio de Feromonas: 0.00046204001881750424
# Iteración 7/50 - Mejor Costo Global: 1114.8601714718297 - Promedio de Feromonas: 0.0004012201628145514
# Iteración 8/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00037242907104444915
# Iteración 9/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00035098156125029406
# Iteración 10/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00033862431491484343
# Iteración 11/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003328219610708168
# Iteración 12/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00032484314785518904
# Iteración 13/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00032779661491680713
# Iteración 14/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003300716596376691
# Iteración 15/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003202738383445764
# Iteración 16/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003195595070480976
# Iteración 17/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00031307558563646934
# Iteración 18/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003094731860773033
# Iteración 19/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003076005320147924
# Iteración 20/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00032269983832439907
# Iteración 21/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003259946636174049
# Iteración 22/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00033326043977462415
# Iteración 23/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003342313079873139
# Iteración 24/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00033585362127604564
# Iteración 25/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00033692237496555977
# Iteración 26/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00033103090586075073
# Iteración 27/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003285621470817566
# Iteración 28/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003262508593223681
# Iteración 29/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00032541853296185353
# Iteración 30/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003269030258331035
# Iteración 31/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003258640860447263
# Iteración 32/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00032531241901937667
# Iteración 33/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00032626941853636964
# Iteración 34/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003240937010166179
# Iteración 35/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00032060826649974627
# Iteración 36/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003181533684581882
# Iteración 37/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00031778350866469416
# Iteración 38/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00031686685481270907
# Iteración 39/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003168676179179459
# Iteración 40/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00031725110504083167
# Iteración 41/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003165214004784514
# Iteración 42/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003157870154475593
# Iteración 43/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.000315945502646309
# Iteración 44/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003134609082987566
# Iteración 45/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003122109901884965
# Iteración 46/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003123164854528792
# Iteración 47/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003138043206170424
# Iteración 48/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.0003125864042069591
# Iteración 49/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00031352112860323747
# Iteración 50/50 - Mejor Costo Global: 1095.653980900426 - Promedio de Feromonas: 0.00031522820906895645
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 32 Tiempo Servicio: 10, Ventana Tiempo: (31, 100)) -> 33 Tiempo Servicio: 10, Ventana Tiempo: (87, 158)) -> 31 Tiempo Servicio: 10, Ventana Tiempo: (200, 237)) -> 35 Tiempo Servicio: 10, Ventana Tiempo: (283, 344)) -> 37 Tiempo Servicio: 10, Ventana Tiempo: (383, 434)) -> 38 Tiempo Servicio: 10, Ventana Tiempo: (479, 522)) -> 39 Tiempo Servicio: 10, Ventana Tiempo: (567, 624)) -> 36 Tiempo Servicio: 10, Ventana Tiempo: (665, 716)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana ...
# Costo Ruta 1: 1095.653980900426

# %% [markdown]
# 2.MOACS se hace el intento de usar frente pareto para usar como objetivo tiempo y costo

# %%
import pandas as pd
import numpy as np

# Establecer semilla aleatoria para reproducibilidad
random_seed = np.random.randint(1, 1000)  # Genera un número aleatorio entre 1 y 1000
np.random.seed(random_seed)

# Calcular la distancia entre dos puntos
def calcular_distancia(punto1, punto2):
    return np.linalg.norm(np.array(punto1) - np.array(punto2))

# Calcular el costo de una ruta dadas las coordenadas de los clientes
def calcular_costo_ruta(ruta, coordenadas):
    distancias = np.linalg.norm(coordenadas[ruta[:-1]] - coordenadas[ruta[1:]], axis=1)
    return np.sum(distancias)

# Inicializar rutas para cada vehículo
def inicializar_rutas(num_clientes):
    return [[i] for i in range(1, num_clientes)]

# Seleccionar el cliente más cercano a uno dado
def seleccionar_cliente_mas_cercano(cliente_actual, clientes_restantes, coordenadas):
    if not clientes_restantes:
        return None
    ubicacion_actual = coordenadas[cliente_actual]
    distancias = np.linalg.norm(coordenadas[clientes_restantes] - ubicacion_actual, axis=1)
    cliente_mas_cercano = clientes_restantes[np.argmin(distancias)]
    return cliente_mas_cercano

# Verificar si se viola la ventana de tiempo
def se_viola_ventana_tiempo(tiempo_actual, distancia, tiempo_listo, fecha_limite, tiempo_servicio):
    return tiempo_actual + distancia + tiempo_servicio > fecha_limite

# Agregar un cliente a una ruta y verificar si se viola la ventana de tiempo
def agregar_cliente_a_ruta(ruta_actual, cliente, tiempo_actual, coordenadas, df, tolerancia_ventana_tiempo):
    if cliente is not None:
        distancia = calcular_distancia(coordenadas[ruta_actual[-1]], coordenadas[cliente])
        tiempo_servicio = df.at[cliente, 'TIEMPO DE SERVICIO']
        tiempo_listo = df.at[cliente, 'TIEMPO LISTO']
        fecha_limite = df.at[cliente, 'FECHA LÍMITE']

        if not se_viola_ventana_tiempo(tiempo_actual, distancia, tiempo_listo, fecha_limite, tiempo_servicio):
            ruta_actual.append(cliente)
            tiempo_actual = max(tiempo_actual + distancia + tiempo_servicio, tiempo_listo)
            return tiempo_actual, True
        else:
            return tiempo_actual, False
    else:
        return tiempo_actual, False

# Inicializar feromonas
def inicializar_feromonas(num_clientes):
    return np.ones((num_clientes, num_clientes)) / num_clientes

# Actualizar feromonas
def actualizar_feromonas(feromonas, rutas, costo_rutas, evaporation_rate=0.5):
    feromonas *= (1.0 - evaporation_rate)  # Evaporación
    for ruta, costo in zip(rutas, costo_rutas):
        for i in range(len(ruta) - 1):
            # Actualización de feromonas utilizando la ecuación clásica
            feromonas[ruta[i], ruta[i + 1]] += 1.0 / costo
            feromonas[ruta[i + 1], ruta[i]] += 1.0 / costo

# Construir solución de la hormiga
def construir_solucion_hormiga(feromonas, visibilidad, tolerancia_ventana_tiempo=0):
    num_clientes = feromonas.shape[0]
    coordenadas = df[['XCOORD.', 'YCOORD.']].values
    ruta_hormiga = [0]  # Comienza en el depósito
    tiempo_actual = 0

    while len(ruta_hormiga) < num_clientes:
        clientes_restantes = [c for c in range(num_clientes) if c not in ruta_hormiga]
        probabilidad = np.zeros(num_clientes)

        for cliente in clientes_restantes:
            probabilidad[cliente] = (feromonas[ruta_hormiga[-1], cliente] ** 1.0) * (visibilidad[ruta_hormiga[-1], cliente] ** 2.0)

        if np.random.rand() < 0.9:
            # Elegir la mejor (explotación)
            siguiente_cliente = np.argmax(probabilidad)
        else:
            # Elegir según la probabilidad proporcional (exploración)
            probabilidad /= np.sum(probabilidad)
            probabilidad[clientes_restantes] /= np.sum(probabilidad[clientes_restantes])
            siguiente_cliente = np.random.choice(clientes_restantes, p=probabilidad[clientes_restantes], replace=False)

        tiempo_actual, agregado = agregar_cliente_a_ruta(ruta_hormiga, siguiente_cliente, tiempo_actual, coordenadas, df, tolerancia_ventana_tiempo)

        if not agregado:
            # Si no se pudo agregar el cliente, regresar al depósito y continuar
            ruta_hormiga.append(0)
            tiempo_actual = 0

    return ruta_hormiga

# Calcular la visibilidad entre las ciudades
def calcular_visibilidad(coordenadas):
    num_clientes = coordenadas.shape[0]
    visibilidad = np.zeros((num_clientes, num_clientes))

    for i in range(num_clientes):
        for j in range(i + 1, num_clientes):
            dist = calcular_distancia(coordenadas[i], coordenadas[j])
            visibilidad[i, j] = 1.0 / dist
            visibilidad[j, i] = 1.0 / dist

    return visibilidad

# Modified function to calculate the time for a route
def calcular_tiempo_ruta(ruta, coordenadas, df):
    # Assuming time is the sum of service times for each customer in the route
    tiempo_servicio = sum(df.at[cliente, 'TIEMPO DE SERVICIO'] for cliente in ruta[1:-1])
    return tiempo_servicio

def calcular_pareto_front(costos, tiempos):
    combined_objectives = np.column_stack((costos, tiempos))

    sorted_indices = np.lexsort(combined_objectives.T)

    # Keep only the non-dominated solutions
    pareto_front = [sorted_indices[0]]
    for i in range(1, len(sorted_indices)):
        if combined_objectives[sorted_indices[i], 1] < combined_objectives[pareto_front[-1], 1]:
            pareto_front.append(sorted_indices[i])

    return pareto_front

# Modified moaco function to return Pareto front solutions
def moaco(df, num_hormigas, num_iteraciones, tolerancia_ventana_tiempo=0,
          ALPHA=1.0, BETA=2.0, RHO=0.5, Q0=0.9):
    num_clientes = len(df)
    coordenadas = df[['XCOORD.', 'YCOORD.']].values

    feromonas = inicializar_feromonas(num_clientes)
    visibilidad = calcular_visibilidad(coordenadas)

    pareto_front_solutions = []

    mejor_solucion_global = None
    mejor_costo_global = float('inf')

    for iteracion in range(num_iteraciones):
        soluciones_hormigas = []

        for _ in range(num_hormigas):
            solucion_hormiga = construir_solucion_hormiga(feromonas, visibilidad, tolerancia_ventana_tiempo)
            soluciones_hormigas.append(solucion_hormiga)

        costo_rutas_hormigas = [calcular_costo_ruta(solucion, coordenadas) for solucion in soluciones_hormigas]
        tiempo_rutas_hormigas = [calcular_tiempo_ruta(solucion, coordenadas, df) for solucion in soluciones_hormigas]

        pareto_front = calcular_pareto_front(costo_rutas_hormigas, tiempo_rutas_hormigas)
        pareto_front_solutions.extend([soluciones_hormigas[idx] for idx in pareto_front])

        # Update pheromones
        actualizar_feromonas(feromonas, soluciones_hormigas, costo_rutas_hormigas, evaporation_rate=RHO)

        for idx in pareto_front:
            if costo_rutas_hormigas[idx] < mejor_costo_global:
                mejor_costo_global = costo_rutas_hormigas[idx]
                mejor_solucion_global = soluciones_hormigas[idx]

        promedio_feromonas = np.mean(feromonas)

        # Print information
        print(f"Iteración {iteracion + 1}/{num_iteraciones} - Mejor Costo Global: {mejor_costo_global} - Promedio de Feromonas: {promedio_feromonas}")

    return pareto_front_solutions


# Imprimir la solución (rutas y costos)
# Agregar esto a la función imprimir_solucion
def imprimir_solucion(rutas, df):
    for i, ruta in enumerate(rutas):
        print(f"Ruta {i + 1}: Depósito -> ", end="")
        for cliente in ruta:
            print(f"{cliente} Tiempo Servicio: {df.at[cliente, 'TIEMPO DE SERVICIO']}, Ventana Tiempo: ({df.at[cliente, 'TIEMPO LISTO']}, {df.at[cliente, 'FECHA LÍMITE']})) -> ", end="")
        print("Depósito")
        print(f"Costo Ruta {i + 1}: {calcular_costo_ruta(ruta, df[['XCOORD.', 'YCOORD.']].values)}")
        print()


if __name__ == '__main__':
    print("Dataset")
    print(df)
    print()

    num_hormigas = 10
    num_iteraciones = 20
    tolerancia_ventana_tiempo = 30

    pareto_front_solutions = moaco(df, num_hormigas, num_iteraciones, tolerancia_ventana_tiempo)

    # Print Pareto front solutions
    for i, solution in enumerate(pareto_front_solutions):
        print(f"Pareto Front Solution {i + 1}")
        imprimir_solucion([solution], df)
# Out:
# Dataset
#      CUST NO.  XCOORD.  YCOORD.  DEMAND  TIEMPO LISTO  FECHA LÍMITE  \
# 0           0       40       50       0             0          1236
# 1           1       45       68      10           912           967
# 2           2       45       70      30           825           870
# 3           3       42       66      10            65           146
# 4           4       42       68      10           727           782
# ..        ...      ...      ...     ...           ...           ...
# 96         96       60       80      10            95           156
# 97         97       60       85      30           561           622
# 98         98       58       75      20            30            84
# 99         99       55       80      10           743           820
# 100       100       55       85      20           647           726
#
#      TIEMPO DE SERVICIO
# 0                     0
# 1                    10
# 2                    10
# 3                    10
# 4                    10
# ..                  ...
# 96                   10
# 97                   10
# 98                   10
# 99                   10
# 100                  10
#
# [101 rows x 7 columns]
#
# Iteración 1/20 - Mejor Costo Global: 1380.0690142281328 - Promedio de Feromonas: 0.005102615109105419
# Iteración 2/20 - Mejor Costo Global: 1294.2783572241894 - Promedio de Feromonas: 0.00270422463168233
# Iteración 3/20 - Mejor Costo Global: 1294.2783572241894 - Promedio de Feromonas: 0.0015116540914352932
# Iteración 4/20 - Mejor Costo Global: 1270.8714321684142 - Promedio de Feromonas: 0.0009122062061439107
# Iteración 5/20 - Mejor Costo Global: 1270.8714321684142 - Promedio de Feromonas: 0.0006109496802060515
# Iteración 6/20 - Mejor Costo Global: 1270.8714321684142 - Promedio de Feromonas: 0.00046549144292079954
# Iteración 7/20 - Mejor Costo Global: 1266.957172503775 - Promedio de Feromonas: 0.000391297898354196
# Iteración 8/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.00035672231975417704
# Iteración 9/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.0003415375435216764
# Iteración 10/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.00033083785183684976
# Iteración 11/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.00032643457351327345
# Iteración 12/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.0003208610828629357
# Iteración 13/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.00032779012369312026
# Iteración 14/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.0003194031840779144
# Iteración 15/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.00031831513071027437
# Iteración 16/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.00032300686810922326
# Iteración 17/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.00032812378397443424
# Iteración 18/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.0003286688876242935
# Iteración 19/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.0003252867820091899
# Iteración 20/20 - Mejor Costo Global: 1186.2814929440913 - Promedio de Feromonas: 0.0003256376072786443
# Pareto Front Solution 1
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 19 Tiempo Servicio: 10, Ventana Tiempo: (278, 345)) -> 15 Tiempo Servicio: 10, Ventana Tiempo: (384, 429)) -> 16 Tiempo Servicio: 10, Ventana Tiempo: (475, 528)) -> 14 Tiempo Servicio: 10, Ventana Tiempo: (567, 620)) -> 12 Tiempo Servicio: 10, Ventana Tiempo: (652, 721)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, ...
# Costo Ruta 1: 1380.0690142281328
#
# Pareto Front Solution 2
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236 ...
# Costo Ruta 1: 1294.2783572241894
#
# Pareto Front Solution 3
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 99 Tiempo Servicio: 10, Ventana Tiempo: (743, 820)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1 ...
# Costo Ruta 1: 1338.5253037600958
#
# Pareto Front Solution 4
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816 ...
# Costo Ruta 1: 1270.8714321684142
#
# Pareto Front Solution 5
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 86 Tiempo Servicio: 10, Ventana Tiempo: (173, 238)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236 ...
# Costo Ruta 1: 1279.5445123569516
#
# Pareto Front Solution 6
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 98 Tiempo Servicio: 10, Ventana Tiempo: (30, 84)) -> 96 Tiempo Servicio: 10, Ventana Tiempo: (95, 156)) -> 95 Tiempo Servicio: 10, Ventana Tiempo: (196, 239)) -> 94 Tiempo Servicio: 10, Ventana Tiempo: (285, 336)) -> 93 Tiempo Servicio: 10, Ventana Tiempo: (475, 518)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 12 ...
# Costo Ruta 1: 1329.8242416253236
#
# Pareto Front Solution 7
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224 ...
# Costo Ruta 1: 1266.957172503775
#
# Pareto Front Solution 8
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 87 Tiempo Servicio: 10, Ventana Tiempo: (85, 144)) -> 86 Tiempo Servicio: 10, Ventana Tiempo: (173, 238)) -> 84 Tiempo Servicio: 10, Ventana Tiempo: (458, 523)) -> 85 Tiempo Servicio: 10, Ventana Tiempo: (555, 612)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: ( ...
# Costo Ruta 1: 1186.2814929440913
#
# Pareto Front Solution 9
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316 ...
# Costo Ruta 1: 1319.9814378849
#
# Pareto Front Solution 10
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 99 Tiempo Servicio: 10, Ventana Tiempo: (743, 820)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 97 Tiempo Servicio: 10, Ventana Tiempo: (561, 622)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 98 Tiempo Servicio: 10, Ventana Tiempo: (30, 84)) -> 96 Tiempo Servicio: 10, Ventana Tiempo: (95, 156)) -> 95 Tiempo Servicio: 10, Ventana Tiempo: (196, 239)) -> 94 Tiempo Servicio: 10, Ventana Tiempo: (285, 336)) -> 93 Tiempo Servicio: 10, Ventana Tiempo: (475, 518)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 36 Tiempo Servicio: 10, Ventana Tiempo: ( ...
# Costo Ruta 1: 1401.8890514571908
#
# Pareto Front Solution 11
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 87 Tiempo Servicio: 10, Ventana Tiempo: (85, 144)) -> 86 Tiempo Servicio: 10, Ventana Tiempo: (173, 238)) -> 84 Tiempo Servicio: 10, Ventana Tiempo: (458, 523)) -> 85 Tiempo Servicio: 10, Ventana Tiempo: (555, 612)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 97 Tiempo Servicio: 10, Ventana Tiempo: (561, 622)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 83 Tiempo Servicio: 10, Ventana Tiempo: (265, 338)) -> 82 Tiempo Servicio: 10, Ventana Tiempo: (369, 420)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: ...
# Costo Ruta 1: 1297.3540215482599
#
# Pareto Front Solution 12
# ...
# Costo Ruta 1: 1301.3127964301423
#
# Pareto Front Solution 18
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 51 Tiempo Servicio: 10, Ventana Tiempo: (725, 786)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 12 Tiempo Servicio: 10, Ventana Tiempo: (652, 721)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 84 Tiempo Servicio: 10, Ventana Tiempo: (458, 523)) -> 85 Tiempo Servicio: 10, Ventana Tiempo: (555, 612)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 36 Tiempo Servicio: 10, Ventana Tiempo: (665, 716)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 99 Tiempo Servicio: 10, Ventana  ...
# Costo Ruta 1: 1284.8180856642816
#
# Pareto Front Solution 19
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 12 Tiempo Servicio: 10, Ventana Tiempo: (652, 721)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 13 Tiempo Servicio: 10, Ventana Tiempo: (30, 92)) -> 17 Tiempo Servicio: 10, Ventana Tiempo: (99, 148)) -> 18 Tiempo Servicio: 10, Ventana Tiempo: (179, 254)) -> 19 Tiempo Servicio: 10, Ventana Tiempo: (278, 345)) -> 15 Tiempo Servicio: 10, Ventana Tiempo: (384, 429)) -> 16 Tiempo Servicio: 10, Ventana Tiempo: (475, 528)) -> 14 Tiempo Servicio: 10, Ventana Tiempo: (567, 620)) -> 100 Tiempo Servicio: 10, Ventana Tiempo: (647, 726)) -> 99 Tiempo Servicio: 10, Ventana Tiempo: (743, 820)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 84 Tiempo Servicio: 10, Ventana Tiempo: (458, 523)) -> 85 Tiempo Servicio: 10, Ventana Tiempo: (555, 612)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Ti ...
# Costo Ruta 1: 1320.353134844309
#
# Pareto Front Solution 20
# Ruta 1: Depósito -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 21 Tiempo Servicio: 10, Ventana Tiempo: (914, 965)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 20 Tiempo Servicio: 10, Ventana Tiempo: (10, 73)) -> 22 Tiempo Servicio: 10, Ventana Tiempo: (812, 883)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 23 Tiempo Servicio: 10, Ventana Tiempo: (732, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 75 Tiempo Servicio: 10, Ventana Tiempo: (997, 1068)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 67 Tiempo Servicio: 10, Ventana Tiempo: (12, 77)) -> 65 Tiempo Servicio: 10, Ventana Tiempo: (76, 129)) -> 63 Tiempo Servicio: 10, Ventana Tiempo: (171, 218)) -> 62 Tiempo Servicio: 10, Ventana Tiempo: (262, 317)) -> 66 Tiempo Servicio: 10, Ventana Tiempo: (826, 875)) -> 69 Tiempo Servicio: 10, Ventana Tiempo: (916, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 68 Tiempo Servicio: 10, Ventana Tiempo: (734, 777)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 5 Tiempo Servicio: 10, Ventana Tiempo: (15, 67)) -> 3 Tiempo Servicio: 10, Ventana Tiempo: (65, 146)) -> 4 Tiempo Servicio: 10, Ventana Tiempo: (727, 782)) -> 2 Tiempo Servicio: 10, Ventana Tiempo: (825, 870)) -> 1 Tiempo Servicio: 10, Ventana Tiempo: (912, 967)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 91 Tiempo Servicio: 10, Ventana Tiempo: (836, 889)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 7 Tiempo Servicio: 10, Ventana Tiempo: (170, 225)) -> 8 Tiempo Servicio: 10, Ventana Tiempo: (255, 324)) -> 9 Tiempo Servicio: 10, Ventana Tiempo: (534, 605)) -> 6 Tiempo Servicio: 10, Ventana Tiempo: (621, 702)) -> 26 Tiempo Servicio: 10, Ventana Tiempo: (622, 701)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 43 Tiempo Servicio: 10, Ventana Tiempo: (16, 80)) -> 42 Tiempo Servicio: 10, Ventana Tiempo: (68, 149)) -> 41 Tiempo Servicio: 10, Ventana Tiempo: (166, 235)) -> 40 Tiempo Servicio: 10, Ventana Tiempo: (264, 321)) -> 44 Tiempo Servicio: 10, Ventana Tiempo: (359, 412)) -> 45 Tiempo Servicio: 10, Ventana Tiempo: (541, 600)) -> 50 Tiempo Servicio: 10, Ventana Tiempo: (815, 880)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 10 Tiempo Servicio: 10, Ventana Tiempo: (357, 410)) -> 11 Tiempo Servicio: 10, Ventana Tiempo: (448, 505)) -> 84 Tiempo Servicio: 10, Ventana Tiempo: (458, 523)) -> 85 Tiempo Servicio: 10, Ventana Tiempo: (555, 612)) -> 88 Tiempo Servicio: 10, Ventana Tiempo: (645, 708)) -> 89 Tiempo Servicio: 10, Ventana Tiempo: (737, 802)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 47 Tiempo Servicio: 10, Ventana Tiempo: (1054, 1127)) -> 49 Tiempo Servicio: 10, Ventana Tiempo: (1001, 1066)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 46 Tiempo Servicio: 10, Ventana Tiempo: (448, 509)) -> 48 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 59 Tiempo Servicio: 10, Ventana Tiempo: (651, 740)) -> 64 Tiempo Servicio: 10, Ventana Tiempo: (632, 693)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 24 Tiempo Servicio: 10, Ventana Tiempo: (65, 144)) -> 25 Tiempo Servicio: 10, Ventana Tiempo: (169, 224)) -> 27 Tiempo Servicio: 10, Ventana Tiempo: (261, 316)) -> 28 Tiempo Servicio: 10, Ventana Tiempo: (546, 593)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 52 Tiempo Servicio: 10, Ventana Tiempo: (912, 969)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 29 Tiempo Servicio: 10, Ventana Tiempo: (358, 405)) -> 30 Tiempo Servicio: 10, Ventana Tiempo: (449, 504)) -> 34 Tiempo Servicio: 10, Ventana Tiempo: (751, 816)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 74 Tiempo Servicio: 10, Ventana Tiempo: (353, 412)) -> 72 Tiempo Servicio: 10, Ventana Tiempo: (450, 505)) -> 61 Tiempo Servicio: 10, Ventana Tiempo: (531, 610)) -> 0 Tiempo Servicio: 0, Ventana Tiempo: (0, 1236)) -> 90 Tiempo Servicio: 10, Ventana Tiempo: (20, 84)) -> 87 Tiempo Servicio: 10, Ventana Tiempo: (85, 144)) -> 86 Tiempo Servicio: 10, Ventana Tiempo ...
# Costo Ruta 1: 1189.6682681927514
